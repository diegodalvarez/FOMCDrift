# %% [markdown]
# # Background Data Analysis, Data Quality, and Framework for backtesting and performance measurement

# %% [markdown]
# This notebook will examine the data, look at the defined trading windows, and setup the framework for building the backtests and measuring results.

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import datetime as dt
import statsmodels.api as sm

import matplotlib.pyplot as plt
from   matplotlib.patches import Patch

# %% [markdown]
# # Paths and Global Variables

# %%
day_renamer = {
    "day_after"   : "Day After",
    "day_before"  : "Day Before",
    "post_meeting": "Post Meeting",
    "pre_meeting" : "Pre Meeting"}

zone_renamer = {
    "zone1": "Day Before",
    "zone2": "Before Meeting",
    "zone3": "After Meeting",
    "zone4": "Day After"}

replacer = {**day_renamer, **zone_renamer}

# %%
day_renamer_ = {
    "Day After"   : "Day\nAfter",
    "Day Before"  : "Day\nBefore",
    "Post Meeting": "Post\nMeeting",
    "Pre Meeting" : "Pre\nMeeting"}

plot_replacer = {**day_renamer_}

# %%
float_format="%.2f"

# %%
note_path = os.getcwd()
repo_path = os.path.abspath(os.path.join(note_path, ".."))
data_path = os.path.join(repo_path, "data")
zone_path = os.path.join(data_path, "ZoneImputedFirstRateData")

# %% [markdown]
# # Data Quality and EDA

# %% [markdown]
# We picked our predefined trading windows and then sliced the 1 minute bar data at that level and now we are examining the number of data points.

# %%
df_raw = (pd
    .read_parquet(
        path   = zone_path,
        engine = "pyarrow"))

# %% [markdown]
# We can use the prior bar's close to work with the open price.

# %%
(df_raw
    [["ticker", "variable", "meeting_id"]]
    .groupby(["ticker", "variable"])
    .agg("count")
    .reset_index()
    .rename(columns = {
        "variable": "",
        "ticker"  : "Ticker"})
    .pivot(index = "Ticker", columns = "", values = "meeting_id")
    .rename(columns = {
        "missing"    : "Missing",
        "open"       : "Orig Open",
        "prior_close": "Prior Close"}))
# Out:
#         Missing  Orig Open  Prior Close
# Ticker
# TN          732      77445         2267
# UB          818     126549         2681
# US         2280     146353         1021
# ZF         1231     144314          887
# ZN         1526     146072          219
# ZQ        79533      22777        10239
# ZT         3298     136377         7570

# %% [markdown]
# # Start by Analyzing Returns

# %% [markdown]
# We'll just examine the returns for the single day

# %%
path = r"A:\GitHub\FOMCDrift\data\ZoneFirstRateData"
df_meeting_id = (pd
    .read_parquet(path = path, engine = "pyarrow")
    [["fomc_date", "meeting_id"]]
    .drop_duplicates())

# %%
path   = r"A:\GitHub\FOMCDrift\data\RawFirstRateData"
df_raw = (pd
    .read_parquet(path = path, engine = "pyarrow")
    .assign(
        exact_date      = lambda x: pd.to_datetime(x.fomc_date.astype(str) + " " + str(dt.time(hour = 12 + 2, minute = 0))),
        days_to_meeting = lambda x: x.date - x.exact_date,
        tmp             = lambda x: x.days_to_meeting.dt.days)
    .loc[lambda x: (x.tmp >= -2) & (x.tmp < 3)])

# %%
tickers = [
    ticker for ticker in df_raw.ticker.drop_duplicates().to_list()
    if ticker != "ZQ"]

# %%
df_rtn = (df_raw
    .loc[lambda x: x.variable == "open"]
    .merge(right = df_meeting_id, how = "inner", on = ["fomc_date"])
    [["ticker", "days_to_meeting", "meeting_id", "value"]]
    .set_index("days_to_meeting")
    .groupby(["ticker", "meeting_id"])
    .apply(lambda x: x.sort_index().value.diff() / x.sort_index().value.diff().ewm(span = 10, adjust = False).std())
    .to_frame(name = "rtn")
    .assign(rtn = lambda x: np.where(np.abs(x.rtn) > 50, np.nan, x.rtn))
    .reset_index())

# %%
fig, axes = plt.subplots(ncols = len(tickers) // 2, nrows =2, figsize = (20,10))

for ticker, ax in zip(tickers, axes.flatten()):

    (df_rtn
        .loc[lambda x: x.ticker == ticker]
        .pivot(index = "days_to_meeting", columns = "meeting_id", values = "rtn")
        .fillna(0)
        .cumsum()
        .plot(
            title  = ticker,
            ax     = ax,
            legend = False,
            alpha  = 0.4,
            xlabel = "Days to FOMC",
            ylabel = "Cuml. PnL"))

fig.suptitle("Cumulative Vol-Normalized PnL around FOMC Annoucement")
plt.tight_layout()

# %%
(df_rtn
    .dropna()
    .drop(columns = ["meeting_id"])
    .loc[lambda x: x.ticker.isin(tickers)]
    .groupby(["days_to_meeting", "ticker"])
    .agg("mean")
    .reset_index()
    .rename(columns = {"ticker": ""})
    .pivot(index = "days_to_meeting", columns = "", values = "rtn")
    .cumsum()
    .plot(
        ylabel  = "Cuml. PnL",
        title   = "Average Cumulative PnL per Each FOMC Announcement",
        xlabel  = "Days to FOMC",
        figsize = (8,6)))

plt.show()

# %%
df_tmp_raw = (df_raw
    .loc[lambda x: x.variable == "open"]
    .merge(right = df_meeting_id, how = "inner", on = ["fomc_date"])
    [["ticker", "days_to_meeting", "meeting_id", "value"]]
    .set_index("days_to_meeting")
    .groupby(["ticker", "meeting_id"])
    .apply(lambda x: x.sort_index().value.diff())
    .to_frame(name = "rtn")
    .assign(rtn = lambda x: np.where(np.abs(x.rtn) > 50, np.nan, x.rtn))
    .reset_index())

# %%
fig, axes = plt.subplots(ncols = len(tickers) // 2, nrows =2, figsize = (16,8))

for ticker, ax in zip(tickers, axes.flatten()):

    (df_tmp_raw
        .loc[lambda x: x.ticker == x.ticker.min()]
        .rtn
        .plot(
            kind   = "hist", 
            bins   = 50,
            logy   = True,
            ax     = ax,
            xlabel = r"$\Delta P_t$",
            ylabel = "Frequency (Log)",
            title  = ticker))

fig.suptitle("Distribution of Difference Prices Around FOMC Date")
plt.tight_layout()

# %% [markdown]
# # Defining the Tradeable Window

# %%
df_tmp_fomc = (df_meeting_id
    .sample(frac = 1, random_state = 42)
    .head(40))

# %%
slicer = pd.Timedelta(days=-2, hours=12, minutes=30)

df_tmp = (df_raw
    .loc[lambda x: x.variable == "open"]
    .loc[lambda x: x.ticker == "TN"]
    .merge(right = df_tmp_fomc, how = "inner", on = ["fomc_date"])
    .assign(
        total_seconds = lambda x: x.days_to_meeting.dt.total_seconds(),
        time          = lambda x: pd.to_datetime(x.date.dt.time, format = "%H:%M:%S").dt.time)
    .loc[lambda x: slicer <= x.days_to_meeting]
    .pivot(index = ["days_to_meeting", "total_seconds", "fomc_date"], columns = "meeting_id", values = "value")
    .ffill()
    .diff()
    .reset_index())

# %%
path  = r"A:\GitHub\FOMCDrift\data\ZoneFirstRateData"
files = ([
    file for file in os.listdir(path)
    if file.split("_")[0] == "TN"])

paths = [os.path.join(path, file) for file in files]

# %%
ticks = (
    df_tmp[["total_seconds", "days_to_meeting"]]
    .drop_duplicates()
    .assign(days_to_meeting = lambda x: x.days_to_meeting.astype(str).str.replace("days ", "days\n").str[:-3])
    .sort_values("total_seconds")
)

ticks = ticks.iloc[
    np.linspace(0, len(ticks) - 1, 10).astype(int)
]

# %%
fig, axes = plt.subplots(ncols = 2, figsize = (20,6))

(df_tmp
    .drop(columns = ["fomc_date", "days_to_meeting"])
    .set_index("total_seconds")
    .cumsum()
    .plot(
        colormap = "Blues",
        alpha    = 0.6,
        ax       = axes[0],
        legend   = False,
        title    = "Cumulative Minutely PnL"))

(df_tmp
    .drop(columns = ["fomc_date", "days_to_meeting"])
    .set_index("total_seconds")
    .apply(lambda x: x / x.ewm(span = 10, adjust = False).std())
    .cumsum()
    .plot(
        alpha    = 0.6,
        ax       = axes[1],
        legend   = False,
        colormap = "Blues",
        title    = "Cumulative Volatility-Normalized Minutely PnL"))

for ax in axes.flatten(): 
    ax.set_ylabel("Cumulative PnL")
    ax.set_xlabel("Days to Meeting")

handles = []
labels  = []

for path in paths: 
    for ax in axes.flatten():
    
        x = (pd
            .read_parquet(path = path, engine = "pyarrow")
            .assign(
                exact_date      = lambda x: pd.to_datetime(x.fomc_date.astype(str) + " " + str(dt.time(hour = 12 + 2, minute = 0))),
                days_to_meeting = lambda x: x.date - x.exact_date,
                total_seconds   = lambda x: x.days_to_meeting.dt.total_seconds())
            .total_seconds
            .drop_duplicates())
    
        lines = ax.lines
        y_max = max(line.get_ydata().max() for line in lines)
        y_min = min(line.get_ydata().min() for line in lines)
        name  = path.split("\\")[-1].split("_")[-1].split(".")[0]

        patch = ax.fill_between(
            x,
            y_min,
            y_max,
            alpha=0.7,
            label=name)
        
        if ax is axes[0]:
            handles.append(patch)
            labels.append(zone_renamer[name])

for ax in axes.flatten():
    ax.legend(handles, labels, loc="lower left")
    ax.set_xticks(ticks["total_seconds"])
    ax.set_xticklabels(ticks["days_to_meeting"].astype(str))

fig.suptitle("Cumulative Returns of Some Sample Returns of TN Around FOMC Announcement")
plt.show()

# %% [markdown]
# # Examining the returns of the trading zones

# %%
path    = r"A:\GitHub\FOMCDrift\data\ZoneImputedFirstRateData"
df_zone = (pd
    .read_parquet(path = path)
    .loc[lambda x: x.ticker != "ZQ"]
    .set_index("date")
    [["meeting_id", "ticker", "contract", "impute_open", "zone", "name"]])

# %% [markdown]
# When analyzing the full sample annualized sharpe the values are quite high.

# %%
df_pnl = (df_zone
    .groupby(["meeting_id", "ticker", "contract", "zone", "name"])
    .apply(lambda x: x.sort_index().impute_open.diff())
    .reset_index())

# %%
(df_pnl
    [["ticker", "zone", "name", "impute_open"]]
    .dropna()
    .groupby(["ticker", "zone", "name"])
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252 * 1440))
    .reset_index()
    .pivot(index = "ticker", columns = "name", values = "impute_open"))
# Out:
# name    day_after  day_before  post_meeting  pre_meeting
# ticker
# TN       2.018778   -3.685865      7.090877     7.013917
# UB       0.831093    0.622134      3.903893     3.600797
# US       1.512327    0.708846      3.924581     0.711285
# ZF       2.831985   -1.622197     10.102585    -2.006345
# ZN       2.279268   -1.068059      9.724620    -0.180576
# ZT       1.666313   -0.675011      9.894228    -1.989216

# %% [markdown]
# This is the minutely returns then averaged and standard deviation are calculate then annualized. The scaling effects can lead to overstated sharpes, and thus there needs to be some sort of framework to adjust for this.

# %%
df_hhour_pnl = (df_zone
    .groupby(["meeting_id", "ticker", "contract", "zone", "name"])
    .resample("30min")
    .first()
    .reset_index()
    .set_index("date")
    .groupby(["meeting_id", "ticker", "contract", "zone", "name"])
    .apply(lambda x: x.sort_index().impute_open.diff())
    .reset_index())

# %% [markdown]
# Rather than using minutely PnL take 30 minute PnL to get it in a smoother format.

# %%
(df_hhour_pnl
    .drop(columns = ["date"])
    .dropna()
    [["zone", "name", "ticker", "impute_open"]]
    .groupby(["zone", "name", "ticker"])
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252 * 48))
    .reset_index()
    .pivot(index = "ticker", columns = "name", values = "impute_open"))
# Out:
# name    day_after  day_before  post_meeting  pre_meeting
# ticker
# TN       2.148938   -3.806058      7.483501     8.500850
# UB       0.792412    0.554132      4.057536     3.691740
# US       2.025430    0.630096      3.853529     0.848387
# ZF       3.109760   -1.715732     11.052449    -2.309515
# ZN       2.810715   -1.182219     10.052883    -0.237441
# ZT       2.882489   -0.968846     10.031747    -2.731897

# %% [markdown]
# That likely smoothened out the volatility reltiave to the returns and thus increased the sharpe by a large amount. Below is the table of average futures point change for each period.

# %%
(df_pnl
    [["ticker", "name", "impute_open"]]
    .groupby(["ticker", "name"])
    .agg("mean")
    .reset_index()
    .pivot(index = "ticker", columns = "name", values = "impute_open"))
# Out:
# name    day_after  day_before  post_meeting  pre_meeting
# ticker
# TN       0.000072   -0.000117      0.000576     0.000227
# UB       0.000076    0.000049      0.000696     0.000313
# US       0.000099    0.000041      0.000635     0.000042
# ZF       0.000054   -0.000026      0.000611    -0.000034
# ZN       0.000075   -0.000030      0.000926    -0.000005
# ZT       0.000014   -0.000005      0.000213    -0.000016

# %% [markdown]
# # Calculating the backtest

# %% [markdown]
# One of the problems of generating PnL curves is the following
# 1. non-continuous times
# 2. each contract trading at different durations / vols and thus not normalized

# %%
fig, axes = plt.subplots(ncols = 2, figsize = (20,6))

(df_pnl
    .rename(columns = {"ticker": ""})
    .pivot(index = "date", columns = "", values = "impute_open")
    .cumsum()
    .plot(
        ax = axes[0]))

(df_pnl
    .rename(columns = {"ticker": ""})
    .pivot(index = "date", columns = "", values = "impute_open")
    .apply(lambda x: x / x.ewm(span = 10, adjust = False).std())
    .apply(lambda x: np.where(np.abs(x) > 50, np.nan, x))
    .cumsum()
    .plot(
        ax = axes[1]))

for ax in axes.flatten(): 
    ax.set_ylabel("Cuml. PnL")

axes[0].set_title("Cumulative PnL of Raw PnLs")
axes[1].set_title("Cumulative PnL of Volatility Targeted PnLs Hedged Perfectly and Minutely\nUsing 10d EWMA")
# Out:
# Text(0.5, 1.0, 'Cumulative PnL of Volatility Targeted PnLs Hedged Perfectly and Minutely\nUsing 10d EWMA')

# %% [markdown]
# The PnLs need some sort of volatility targeting to noramlize the returns when we make the portfolio. On the other hand its not possible to hedge, and perfectly as well, at the minutely level. Therefore we need a volatility targeting tool that does the following
# 1. Calcluates a hedge value per every trade
# 2. Keeps the PnL in line with the initial hedge values
# 3. Also use the prior price action data (which isn't present in the trading zones) data, and thus properly hedge.

# %% [markdown]
# # Finding the optimal volatility calculation

# %% [markdown]
# Ideally we want to find a volatility measurement that accurately sets a volatility target. Using the historical data, there are two options
# 1. We can use the prior day's volatility calculation which comes from the data
# 2. We can use the prior event's volatility calculation
#
# At this moment there are arguments for either since the prior day's volatility may capture the macro economic backdrop greater than the prior event, yet the whole point of this repo is to trade a repeatable pattern around FOMC announcements.

# %%
df_event_vol = (df_pnl
    .drop(columns = ["date"])
    .groupby(["meeting_id", "ticker", "contract", "zone", "name"])
    .agg("std")
    .dropna()
    .reset_index()
    .rename(columns = {"impute_open": "vol"}))

# %%
df_lag_vol = (df_event_vol
    .set_index("meeting_id")
    .groupby(["ticker", "contract", "zone", "name"])
    .apply(lambda x: x.sort_index().vol.shift())
    .reset_index()
    .dropna()
    .rename(columns = {"vol": "lag_vol"}))

# %%
df_combined = (df_event_vol
    .merge(right = df_lag_vol, how = "inner", on = ["meeting_id", "ticker", "contract", "zone", "name"]))

# %%
tickers = df_combined.ticker.drop_duplicates().sort_values().to_list()
fig, axes = plt.subplots(ncols = len(tickers) // 2, nrows = 2, figsize = (16,9))

for ticker, ax in zip(tickers, axes.flatten()):

    df_tmp = (df_combined
        .loc[lambda x: x.ticker == ticker]
        .rename(columns = {"zone": ""})
        .replace(replacer))

    (sns.scatterplot(
        ax   = ax,
        data = df_tmp,
        x    = "lag_vol",
        y    = "vol",
        hue  = ""))

    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.set_xlabel("Log-Volatility (Lagged)")
    ax.set_ylabel("Log-Volatility")
    ax.set_title(ticker)

fig.suptitle("Comparing Prior event volatility to current event volatility")
plt.tight_layout()

# %%
tickers = df_combined.ticker.drop_duplicates().sort_values().to_list()
models  = {}

for ticker in tickers: 

    df_tmp = (df_combined
        .loc[lambda x: x.ticker == ticker]
        .set_index("meeting_id")
        [["vol", "lag_vol"]]
        .apply(lambda x: np.log(x))
        .apply(lambda x: np.where(np.abs(x) == np.inf, np.nan, x))
        .apply(lambda x: np.where(x == 0, np.nan, x))
        .dropna())

    model = (sm
        .OLS(
            endog = df_tmp.vol,
            exog  = sm.add_constant(df_tmp.lag_vol))
        .fit())

    models[ticker] = model
# Out:
# C:\Users\Diego\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Diego\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Diego\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_param_list = []

for ticker in tickers:

    tmp_model = models[ticker]
    df_params = tmp_model.params.to_frame(name = "params").reset_index()
    df_tvalue = tmp_model.tvalues.to_frame(name = "tvalue").reset_index()
    df_pvalue = tmp_model.pvalues.to_frame(name = "p_value").reset_index()

    df_add = (df_params
        .merge(right = df_tvalue, how = "inner", on = ["index"])
        .merge(right = df_pvalue, how = "inner", on = ["index"])
        .assign(
            r2     = tmp_model.rsquared,
            ticker = ticker)
        .rename(columns = {"index": "param"}))
    
    df_param_list.append(df_add)

df_params = pd.concat(df_param_list)

# %%
(df_params
    .melt(id_vars = ["param", "ticker", "r2"])
    .pivot(index = ["ticker", "r2"], columns  = ["variable", "param"], values = "value"))
# Out:
# variable           params               tvalue                  p_value  \
# param               const   lag_vol      const    lag_vol         const
# ticker r2
# TN     0.588407 -1.537149  0.613617  -9.661384  14.740991  1.633333e-17
# UB     0.454757 -1.326068  0.559931 -11.553452  14.439916  5.045090e-25
# US     0.493045 -1.405414  0.575178 -12.740763  16.794133  7.895339e-30
# ZF     0.632081 -1.702257  0.640711 -12.947550  21.893373  2.408964e-30
# ZN     0.580100 -1.649499  0.595033 -13.999310  19.807863  3.196406e-34
# ZT     0.628907 -2.022588  0.634962 -13.301382  21.977281  9.859281e-32
#
# variable
# param                 lag_vol
# ticker r2
# TN     0.588407  4.198410e-31
# UB     0.454757  8.817858e-35
# US     0.493045  1.103999e-44
# ZF     0.632081  1.584331e-62
# ZN     0.580100  1.900103e-55
# ZT     0.628907  2.662579e-63

# %%
df_tmp = (df_zone
    .reset_index()
    .assign(tmp_date = lambda x: x.date.dt.date))

df_events = (df_tmp
    [["tmp_date", "meeting_id", "ticker", "contract", "zone", "name"]]
    .drop_duplicates())

# %%
path          = os.path.join(data_path, "Guides", "TradingZones.xlsx")
df_zone_times = pd.read_excel(io = path)

# %%
df_events
# Out:
#           tmp_date  meeting_id ticker contract   zone        name
# 0       2016-01-26       158.0     TN      H16  zone1  day_before
# 361     2016-03-15       159.0     TN      M16  zone1  day_before
# 722     2016-04-26       160.0     TN      M16  zone1  day_before
# 1083    2016-06-14       161.0     TN      U16  zone1  day_before
# 1444    2016-07-26       162.0     TN      U16  zone1  day_before
# ...            ...         ...    ...      ...    ...         ...
# 799835  2025-05-08       233.0     ZT      M25  zone4   day_after
# 800196  2025-06-19       234.0     ZT      U25  zone4   day_after
# 800557  2025-07-31       235.0     ZT      U25  zone4   day_after
# 800918  2025-09-18       236.0     ZT      Z25  zone4   day_after
# 801279  2025-10-30       237.0     ZT      Z25  zone4   day_after
#
# [3130 rows x 6 columns]

# %%
from tqdm.auto import tqdm

df_prior_vols_list = []

for i, row in tqdm(df_events.iterrows(), total=len(df_events), desc="Calculating prior vols"):

    row_dict = row.to_dict()

    cur_date  = row_dict["tmp_date"]
    prev_date = cur_date - pd.Timedelta(days=1)
    ticker    = row_dict["ticker"]
    contract  = row_dict["contract"]

    time_dict = (df_zone_times
        .loc[lambda x: x.zone == row_dict["zone"]]
        .to_dict(orient="records")
        [0])

    start_time, end_time = time_dict["start_time"], time_dict["end_time"]
    
    df_add = (df_raw
        .loc[lambda x: x.variable == "open"]
        .loc[lambda x: x.ticker == ticker]
        .loc[lambda x: x.contract == contract]
        .assign(tmp_date=lambda x: x.date.dt.date)
        .loc[lambda x: x.tmp_date.isin([cur_date, prev_date])]
        .assign(
            date_name=lambda x: np.where(
                x.tmp_date == x.tmp_date.min(),
                "prior_date",
                "cur_date"
            ),
            time=lambda x: x.date.dt.time)
        .loc[lambda x: (start_time <= x.time) & (x.time <= end_time)]
        .pivot(index="time", columns="date_name", values="value")
        .ffill()
        .bfill()
        .diff()
        .agg("std")
        .to_frame(name="vol")
        .T
        .assign(
            ticker=ticker,
            contract=contract,
            zone=row_dict["zone"],
            name=row_dict["name"],
            meeting_id=row_dict["meeting_id"]))

    df_prior_vols_list.append(df_add)
# Out:
# Calculating prior vols:   0%|          | 0/3130 [00:00<?, ?it/s]

# %%
path     = r"A:\GitHub\FOMCDrift\data\Guides\TradingZones.xlsx"
df_zones = (pd
    .read_excel(io = path))

# %%
path = r"A:\GitHub\FOMCDrift\data\Guides\FedMeetings.xlsx"
(pd
    .read_excel(io = path)
    [["date"]])
# Out:
#           date
# 0   1997-02-05
# 1   1997-03-25
# 2   1997-05-20
# 3   1997-07-02
# 4   1997-08-19
# ..         ...
# 237 2025-12-10
# 238 2026-01-28
# 239 2026-03-18
# 240 2026-04-29
# 241 2026-06-17
#
# [242 rows x 1 columns]

# %%
df_trades = (df_zone
    .reset_index()
    [["meeting_id", "ticker", "contract", "zone", "name", "date"]]
    .assign(date = lambda x: pd.to_datetime(x.date).dt.date)
    .drop_duplicates()
    .sort_values(["meeting_id", "contract"])
    .merge(right = df_zones, how = "inner", on = ["zone", "name"])
    .merge(right = df_meeting_id, how = "inner", on = ["meeting_id"])
    .rename(columns = {"date": "trade_date"}))

# %%
raw_path = r"A:\GitHub\FOMCDrift\data\RawFirstRateData"

# %%
for i, row in df_trades.iterrows(): 

    row_dict   = row.to_dict()
    ticker     = row_dict["ticker"]
    read_path  = os.path.join(raw_path, ticker + "_1min.parquet")
    contract   = row_dict["contract"]
    trade_date = row_dict["trade_date"] - pd.Timedelta(days = 1)
    
    display(pd
        .read_parquet(path = read_path, engine = "pyarrow")
        .loc[lambda x: (x.ticker == ticker) & (x.contract == file) & (x.variable == "open")]
        .assign(date = lambda x: pd.to_datetime(x.date))
        .assign(tmp_date = lambda x: pd.to_datetime(x.date).dt.date)
        .sort_values("date"))
    break

# %%
print(os.getcwd())
